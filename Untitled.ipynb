# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('KDDTest+.csv')
data
# Out:
#        duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0             0           tcp   private   REJ          0          0     0
# 1             0           tcp   private   REJ          0          0     0
# 2             2           tcp  ftp_data    SF      12983          0     0
# 3             0          icmp     eco_i    SF         20          0     0
# 4             1           tcp    telnet  RSTO          0         15     0
# ...         ...           ...       ...   ...        ...        ...   ...
# 22539         0           tcp      smtp    SF        794        333     0
# 22540         0           tcp      http    SF        317        938     0
# 22541         0           tcp      http    SF      54540       8314     0
# 22542         0           udp  domain_u    SF         42         42     0
# 22543         0           tcp    sunrpc   REJ          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# ...

# %%
data.head()
# Out:
#    duration protocol_type   service  flag  src_bytes  dst_bytes  land  \
# 0         0           tcp   private   REJ          0          0     0
# 1         0           tcp   private   REJ          0          0     0
# 2         2           tcp  ftp_data    SF      12983          0     0
# 3         0          icmp     eco_i    SF         20          0     0
# 4         1           tcp    telnet  RSTO          0         15     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.04
# 1               0       0    0  ...                    0.00
# 2               0       0    0  ...                    0.61
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    0.31
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.06                         0.00
# 1                    0.06                         0.00
# ...

# %%
data.tail()
# Out:
#        duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 22539         0           tcp      smtp   SF        794        333     0
# 22540         0           tcp      http   SF        317        938     0
# 22541         0           tcp      http   SF      54540       8314     0
# 22542         0           udp  domain_u   SF         42         42     0
# 22543         0           tcp    sunrpc  REJ          0          0     0
#
#        wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 22539               0       0    0  ...                    0.72
# 22540               0       0    0  ...                    1.00
# 22541               0       0    2  ...                    1.00
# 22542               0       0    0  ...                    0.99
# 22543               0       0    0  ...                    0.08
#
#        dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 22539                    0.06                         0.01
# ...

# %%
data.describe()
# Out:
#            duration     src_bytes     dst_bytes          land  wrong_fragment  \
# count  22544.000000  2.254400e+04  2.254400e+04  22544.000000    22544.000000
# mean     218.859076  1.039545e+04  2.056019e+03      0.000311        0.008428
# std     1407.176612  4.727864e+05  2.121930e+04      0.017619        0.142599
# min        0.000000  0.000000e+00  0.000000e+00      0.000000        0.000000
# 25%        0.000000  0.000000e+00  0.000000e+00      0.000000        0.000000
# 50%        0.000000  5.400000e+01  4.600000e+01      0.000000        0.000000
# 75%        0.000000  2.870000e+02  6.010000e+02      0.000000        0.000000
# max    57715.000000  6.282565e+07  1.345927e+06      1.000000        3.000000
#
#              urgent           hot  num_failed_logins     logged_in  \
# count  22544.000000  22544.000000       22544.000000  22544.000000
# mean       0.000710      0.105394           0.021647      0.442202
# ...

# %%
data.shape
# Out:
# (22544, 43)

# %%
data.isnull().sum()
# Out:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22544 entries, 0 to 22543
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   duration                     22544 non-null  int64
#  1   protocol_type                22544 non-null  object
#  2   service                      22544 non-null  object
#  3   flag                         22544 non-null  object
#  4   src_bytes                    22544 non-null  int64
#  5   dst_bytes                    22544 non-null  int64
#  6   land                         22544 non-null  int64
#  7   wrong_fragment               22544 non-null  int64
#  8   urgent                       22544 non-null  int64
#  9   hot                          22544 non-null  int64
#  10  num_failed_logins            22544 non-null  int64
#  11  logged_in                    22544 non-null  int64
#  12  num_compromised              22544 non-null  int64
# ...

# %%
print(data["attack"].value_counts())
# Out:
# attack
# normal             9711
# neptune            4657
# guess_passwd       1231
# mscan               996
# warezmaster         944
# apache2             737
# satan               735
# processtable        685
# smurf               665
# back                359
# snmpguess           331
# saint               319
# mailbomb            293
# snmpgetattack       178
# portsweep           157
# ipsweep             141
# httptunnel          133
# nmap                 73
# pod                  41
# buffer_overflow      20
# multihop             18
# named                17
# ps                   15
# sendmail             14
# rootkit              13
# xterm                13
# teardrop             12
# xlock                 9
# land                  7
# xsnoop                4
# ftp_write             3
# worm                  2
# loadmodule            2
# perl                  2
# sqlattack             2
# udpstorm              2
# phf                   2
# imap                  1
# ...

# %%
ns = data['attack'].value_counts()
ns_values = ns.values
labels = ns.index
plt.figure(figsize=(24, 20))
plt.pie(ns, labels=labels, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'red'])
plt.title('attack')
plt.show()

# %%
# List of columns to keep
important_cols = [
    'duration', 'protocol_type', 'service', 'flag', 
    'src_bytes', 'dst_bytes', 'count', 'srv_count', 
    'serror_rate', 'srv_serror_rate', 'same_srv_rate', 
    'diff_srv_rate', 'dst_host_count', 'dst_host_srv_count', 'attack'
]

# Keep only important columns
data = data[important_cols]

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22544 entries, 0 to 22543
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   duration            22544 non-null  int64
#  1   protocol_type       22544 non-null  object
#  2   service             22544 non-null  object
#  3   flag                22544 non-null  object
#  4   src_bytes           22544 non-null  int64
#  5   dst_bytes           22544 non-null  int64
#  6   count               22544 non-null  int64
#  7   srv_count           22544 non-null  int64
#  8   serror_rate         22544 non-null  float64
#  9   srv_serror_rate     22544 non-null  float64
#  10  same_srv_rate       22544 non-null  float64
#  11  diff_srv_rate       22544 non-null  float64
#  12  dst_host_count      22544 non-null  int64
#  13  dst_host_srv_count  22544 non-null  int64
#  14  attack              22544 non-null  object
# ...

# %%
# Define attack type mapping
attack_mapping = {
    'normal': 'normal',

    # DoS attacks
    'neptune': 'DoS',
    'smurf': 'DoS',
    'teardrop': 'DoS',
    'pod': 'DoS',
    'back': 'DoS',

    # Probe attacks
    'ipsweep': 'Probe',
    'nmap': 'Probe',
    'satan': 'Probe',
    'portsweep': 'Probe',

    # R2L (Remote to Local) attacks
    'warezclient': 'R2L',
    'guess_passwd': 'R2L',
    'ftp_write': 'R2L',
    'imap': 'R2L',
    'phf': 'R2L',
    'warezmaster': 'R2L',
    'multihop': 'R2L',
    'spy': 'R2L',
    'land': 'R2L',

    # U2R (User to Root) attacks
    'buffer_overflow': 'U2R',
    'loadmodule': 'U2R',
    'rootkit': 'U2R',
    'perl': 'U2R'
}

# Apply mapping to attack column
data['attack_category'] = data['attack'].map(attack_mapping)

# %%
test=data.to_csv('test.csv',index=False)

# %%
data.dropna()
# Out:
#        duration protocol_type   service flag  src_bytes  dst_bytes  count  \
# 0             0           tcp   private  REJ          0          0    229
# 1             0           tcp   private  REJ          0          0    136
# 2             2           tcp  ftp_data   SF      12983          0      1
# 5             0           tcp      http   SF        267      14515      4
# 6             0           tcp      smtp   SF       1022        387      1
# ...         ...           ...       ...  ...        ...        ...    ...
# 22538         0          icmp     ecr_i   SF       1032          0     53
# 22539         0           tcp      smtp   SF        794        333      1
# 22540         0           tcp      http   SF        317        938      2
# 22541         0           tcp      http   SF      54540       8314      5
# 22542         0           udp  domain_u   SF         42         42      4
#
#        srv_count  serror_rate  srv_serror_rate  same_srv_rate  diff_srv_rate  \
# ...

# %%
data.isnull().sum()
# Out:
# duration                 0
# protocol_type            0
# service                  0
# flag                     0
# src_bytes                0
# dst_bytes                0
# count                    0
# srv_count                0
# serror_rate              0
# srv_serror_rate          0
# same_srv_rate            0
# diff_srv_rate            0
# dst_host_count           0
# dst_host_srv_count       0
# attack                   0
# attack_category       3750
# dtype: int64

# %%
# Strip whitespace and lowercase just in case
data['attack'] = data['attack'].str.strip()

# Map attacks
data['attack_category'] = data['attack'].map(attack_mapping)

# Check if any unmapped values remain
unmapped = data[data['attack_category'].isna()]['attack'].unique()
print("Unmapped attacks:", unmapped)
# Out:
# Unmapped attacks: ['saint' 'mscan' 'apache2' 'snmpgetattack' 'processtable' 'httptunnel'
#  'ps' 'snmpguess' 'mailbomb' 'named' 'sendmail' 'xterm' 'worm' 'xlock'
#  'xsnoop' 'sqlattack' 'udpstorm']

# %%
extra_mapping = {
    'saint': 'R2L',
    'mscan': 'R2L',
    'apache2': 'R2L',
    'snmpgetattack': 'R2L',
    'processtable': 'R2L',
    'httptunnel': 'R2L',
    'ps': 'R2L',
    'snmpguess': 'R2L',
    'mailbomb': 'R2L',
    'named': 'R2L',
    'sendmail': 'R2L',
    'xterm': 'R2L',
    'xlock': 'R2L',
    'xsnoop': 'R2L',
    'sqlattack': 'U2R',
    'worm': 'U2R'
}

# Update mapping
attack_mapping.update(extra_mapping)

# Apply mapping again
data['attack_category'] = data['attack'].map(attack_mapping)

# %%
data.isnull().sum()
# Out:
# duration              0
# protocol_type         0
# service               0
# flag                  0
# src_bytes             0
# dst_bytes             0
# count                 0
# srv_count             0
# serror_rate           0
# srv_serror_rate       0
# same_srv_rate         0
# diff_srv_rate         0
# dst_host_count        0
# dst_host_srv_count    0
# attack                0
# attack_category       2
# dtype: int64

# %%
# Strip whitespace and lowercase just in case
data['attack'] = data['attack'].str.strip()

# Map attacks
data['attack_category'] = data['attack'].map(attack_mapping)

# Check if any unmapped values remain
unmapped = data[data['attack_category'].isna()]['attack'].unique()
print("Unmapped attacks:", unmapped)
# Out:
# Unmapped attacks: ['udpstorm']

# %%
# Map the remaining attack
data['attack_category'] = data['attack_category'].fillna(
    data['attack'].map({'udpstorm': 'DoS'})
)

# Verify no NaNs remain
print(data['attack_category'].isna().sum())
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# duration              0
# protocol_type         0
# service               0
# flag                  0
# src_bytes             0
# dst_bytes             0
# count                 0
# srv_count             0
# serror_rate           0
# srv_serror_rate       0
# same_srv_rate         0
# diff_srv_rate         0
# dst_host_count        0
# dst_host_srv_count    0
# attack                0
# attack_category       0
# dtype: int64

# %%
data['attack_category'].unique()
# Out:
# array(['DoS', 'normal', 'R2L', 'Probe', 'U2R'], dtype=object)

# %%
# Define integer mapping
category_mapping = {
    'normal': 0,
    'DoS': 1,
    'Probe': 2,
    'R2L': 3,
    'U2R': 4
}

# Apply mapping
data['attack_label'] = data['attack_category'].map(category_mapping)

# Check
print(data[['attack_category', 'attack_label']].head())
# Out:
#   attack_category  attack_label
# 0             DoS             1
# 1             DoS             1
# 2          normal             0
# 3             R2L             3
# 4             R2L             3

# %%
tesla=data.to_csv('tesla.csv',index=False)

# %%
# Features (drop all label columns)
x = data.drop(columns=['attack', 'attack_category', 'attack_label'])

# Target
y = data['attack_label']   # or 'attack_category' if you prefer

# Train-test split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
x
# Out:
#        duration  protocol_type  service  flag  src_bytes  dst_bytes  count  \
# 0             0              1       45     1          0          0    229
# 1             0              1       45     1          0          0    136
# 2             2              1       19     9      12983          0      1
# 3             0              0       13     9         20          0      1
# 4             1              1       55     2          0         15      1
# ...         ...            ...      ...   ...        ...        ...    ...
# 22539         0              1       49     9        794        333      1
# 22540         0              1       22     9        317        938      2
# 22541         0              1       22     9      54540       8314      5
# 22542         0              2       11     9         42         42      4
# 22543         0              1       52     1          0          0      4
#
# ...

# %%
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        3
# 4        3
#         ..
# 22539    0
# 22540    0
# 22541    1
# 22542    0
# 22543    3
# Name: attack_label, Length: 22544, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22544 entries, 0 to 22543
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   duration            22544 non-null  int64
#  1   protocol_type       22544 non-null  object
#  2   service             22544 non-null  object
#  3   flag                22544 non-null  object
#  4   src_bytes           22544 non-null  int64
#  5   dst_bytes           22544 non-null  int64
#  6   count               22544 non-null  int64
#  7   srv_count           22544 non-null  int64
#  8   serror_rate         22544 non-null  float64
#  9   srv_serror_rate     22544 non-null  float64
#  10  same_srv_rate       22544 non-null  float64
#  11  diff_srv_rate       22544 non-null  float64
#  12  dst_host_count      22544 non-null  int64
#  13  dst_host_srv_count  22544 non-null  int64
#  14  attack              22544 non-null  object
# ...

# %%
data[data.select_dtypes(include=['object']).columns] = data.select_dtypes(include=['object']).apply(lambda col: LabelEncoder().fit_transform(col))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22544 entries, 0 to 22543
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   duration            22544 non-null  int64
#  1   protocol_type       22544 non-null  int32
#  2   service             22544 non-null  int32
#  3   flag                22544 non-null  int32
#  4   src_bytes           22544 non-null  int64
#  5   dst_bytes           22544 non-null  int64
#  6   count               22544 non-null  int64
#  7   srv_count           22544 non-null  int64
#  8   serror_rate         22544 non-null  float64
#  9   srv_serror_rate     22544 non-null  float64
#  10  same_srv_rate       22544 non-null  float64
#  11  diff_srv_rate       22544 non-null  float64
#  12  dst_host_count      22544 non-null  int64
#  13  dst_host_srv_count  22544 non-null  int64
#  14  attack              22544 non-null  int32
# ...

# %%
scaler=StandardScaler()
scaler.fit(x_train)
x_train_scaled=scaler.transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
classifiers = {
    "Random Forest": RandomForestClassifier(),
    "AdaBoost": AdaBoostClassifier(),
    "Decision Tree": DecisionTreeClassifier(),
    "KNeighbors": KNeighborsClassifier(),
    "Support Vector Machine": SVC(),
    "XGBoost":XGBClassifier()
}

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
for name, clf in classifiers.items():
    clf.fit(x_train_scaled, y_train)                   
    y_pred = clf.predict(x_test_scaled)            
    accuracy = accuracy_score(y_test, y_pred)       
    print(f'{name} Accuracy: {accuracy:.4f}')    
    print(classification_report(y_test, y_pred))
# Out:
# Random Forest Accuracy: 0.9814
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1925
#            1       1.00      1.00      1.00      1147
#            2       0.95      0.95      0.95       224
#            3       0.98      0.97      0.97      1205
#            4       1.00      0.25      0.40         8
#
#     accuracy                           0.98      4509
#    macro avg       0.98      0.83      0.86      4509
# weighted avg       0.98      0.98      0.98      4509
#
# AdaBoost Accuracy: 0.6505
#               precision    recall  f1-score   support
#
#            0       0.92      0.44      0.60      1925
#            1       0.95      0.68      0.79      1147
#            2       0.57      0.86      0.69       224
#            3       0.55      0.92      0.69      1205
#            4       0.00      0.25      0.01         8
#
#     accuracy                           0.65      4509
# ...

# %%
import time
model = RandomForestClassifier()
start = time.time()
model.fit(x_train_scaled, y_train)
end = time.time()
print("Run Time: %f" % (end - start))
y_pred = model.predict(x_test_scaled)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: ", accuracy)
print(classification_report(y_test, y_pred))
# Out:
# Run Time: 1.907005
# Accuracy:  0.9813705921490352
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1925
#            1       1.00      1.00      1.00      1147
#            2       0.95      0.95      0.95       224
#            3       0.97      0.97      0.97      1205
#            4       1.00      0.38      0.55         8
#
#     accuracy                           0.98      4509
#    macro avg       0.98      0.85      0.89      4509
# weighted avg       0.98      0.98      0.98      4509

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(6,4))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt="d", cmap="Blues", xticklabels=[0,1,2], yticklabels=[0,1,2])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
import pickle
pickle.dump(model,open("model.pickle","wb"))
pickle.dump(scaler,open("scaler.pickle","wb"))

# %%
test=data.to_csv('test.csv',index=False)
